# %%
# Import packages for use in notebook

import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.colors as colors
import pandas as pd
from itertools import cycle, islice

import seaborn as sns

# %matplotlib inline

# %%
os.chdir("/Users/euan-soutter/Desktop/Python/Field_Data/Azerbaijan/Data") # Sets working directory
pd.set_option('display.max_columns', 500) # Displays all columns
df = pd.read_csv("az_beds_mm.csv") # Loads data from working directory and assigns name 'df'
dfcg = pd.read_csv('az_cg.csv')

df.head()# Displays statistical descriptions of df
# Out:
#    Bed_Number  beds_1A  gsize_1A  facies_1A  lith_1A  amal_1A  beds_1B  \
# 0           1      NaN       NaN        NaN      NaN      NaN      NaN
# 1           2      NaN       NaN        NaN      NaN      NaN     80.0
# 2           3     24.0       3.0        4.0      1.0      0.0     24.0
# 3           4      NaN       NaN        NaN      NaN      NaN      NaN
# 4           5     15.0       3.0        4.0      1.0      1.0      NaN
#
#    gsize_1B  facies_1B  lith_1B  amal_1B  beds_1C  gsize_1C  facies_1C  \
# 0       NaN        NaN      NaN      NaN     62.0       4.0        4.0
# 1       5.0        5.0      1.0      1.0     15.0       5.0        6.0
# 2       4.0        4.0      1.0      1.0      NaN       NaN        NaN
# 3       NaN        NaN      NaN      NaN     49.0       4.0        4.0
# 4       NaN        NaN      NaN      NaN      NaN       NaN        NaN
#
#    lith_1C  amal_1C  beds_2A  gsize_2A  facies_2A  lith_2A  amal_2A  beds_3A  \
# 0      1.0      0.0      NaN       NaN        NaN      NaN      NaN      5.0
# 1      1.0      0.0     12.0       4.0        4.0      1.0      0.0      NaN
# 2      NaN      NaN      NaN       NaN        NaN      NaN      NaN      4.0
# 3      1.0      0.0     33.0       4.0        4.0      1.0      1.0      NaN
# 4      NaN      NaN     40.0       4.0        4.0      1.0      1.0      2.0
#
#    gsize_3A  facies_3A  lith_3A  amal_3A  beds_3B  gsize_3B  facies_3B  \
# 0       3.0        3.0      1.0      0.0      3.5       3.0        3.0
# 1       NaN        NaN      NaN      NaN      NaN       NaN        NaN
# 2       3.0        3.0      1.0      0.0      2.5       3.0        3.0
# 3       NaN        NaN      NaN      NaN      7.0       4.0        3.0
# 4       3.0        3.0      1.0      1.0      4.0       5.0        3.0
#
#    lith_3B  amal_3B  beds_4A  gsize_4A  facies_4A  lith_4A  amal_4A  beds_5A  \
# 0      1.0      0.0      NaN       NaN        NaN      NaN      NaN    190.0
# 1      NaN      NaN      NaN       NaN        NaN      NaN      NaN     62.0
# 2      1.0      0.0      NaN       NaN        NaN      NaN      NaN     58.0
# 3      1.0      0.0     15.0       3.0        4.0      1.0      1.0     26.0
# 4      1.0      0.0      8.0       3.0        3.0      1.0      1.0    102.0
#
#    gsize_5A  facies_5A  lith_5A  amal_5A  beds_5B  gsize_5B  facies_5B  \
# 0       3.0        7.0      2.0      0.0     16.0       6.0        2.0
# 1       7.0        5.0      2.0      0.0      6.0       6.0        3.0
# 2       7.0        5.0      2.0      0.0      NaN       NaN        NaN
# 3       5.0        5.0      2.0      0.0     18.0       7.0        2.0
# 4       5.0        7.0      2.0      0.0      7.0       7.0        3.0
#
#    lith_5B  amal_5B  beds_5C  gsize_5C  facies_5C  lith_5C  amal_5C  beds_6A  \
# 0      2.0      0.0      NaN       NaN        NaN      NaN      NaN    137.0
# 1      2.0      0.0      6.0       5.0        3.0      2.0      0.0     35.0
# 2      NaN      NaN      NaN       NaN        NaN      NaN      NaN      NaN
# 3      2.0      0.0      2.0       3.0        3.0      1.0      0.0     80.0
# 4      2.0      1.0      NaN       NaN        NaN      NaN      NaN      7.0
#
#    gsize_6A  facies_6A  lith_6A  amal_6A  beds_7A  gsize_7A  facies_7A  \
# 0       5.0        7.0      2.0      1.0     18.0       8.0        4.0
# 1       5.0        7.0      2.0      1.0      NaN       NaN        NaN
# 2       NaN        NaN      NaN      NaN      4.0       7.0        3.0
# 3       5.0        7.0      2.0      1.0      NaN       NaN        NaN
# 4       5.0        7.0      2.0      1.0      4.0       6.0        3.0
#
#    lith_7A  amal_7A  beds_7B  gsize_7B  facies_7B  lith_7B  amal_7B  beds_7C  \
# 0      2.0      NaN     16.0       3.0        4.0      1.0      NaN    295.0
# 1      NaN      NaN      NaN       NaN        NaN      NaN      NaN     64.0
# 2      2.0      NaN     13.5       4.0        4.0      1.0      NaN     30.0
# 3      NaN      NaN      NaN       NaN        NaN      NaN      NaN      3.0
# 4      2.0      NaN      2.0       5.0        3.0      2.0      NaN      NaN
#
#    gsize_7C  facies_7C  lith_7C  amal_7C  beds_7D  gsize_7D  facies_7D  \
# 0       8.0        7.0      2.0      1.0      3.5       3.0        3.0
# 1       8.0        5.0      2.0      1.0      NaN       NaN        NaN
# 2       8.0        7.0      2.0      1.0      3.0       3.0        3.0
# 3       8.0        3.0      2.0      NaN      NaN       NaN        NaN
# 4       NaN        NaN      NaN      NaN      3.5       5.0        3.0
#
#    lith_7D  amal_7D  beds_8A  gsize_8A  facies_8A  lith_8A  amal_8A  beds_8B  \
# 0      2.0      NaN      NaN       NaN        NaN      NaN      NaN      9.0
# 1      NaN      NaN     15.0       3.0        4.0      2.0      1.0      NaN
# 2      2.0      NaN     17.0       3.0        4.0      2.0      1.0     13.0
# 3      NaN      NaN      6.0       4.0        3.0      2.0      1.0      NaN
# 4      2.0      1.0     10.0       5.0        3.0      2.0      1.0     17.0
#
#    gsize_8B  facies_8B  lith_8B  amal_8B  beds_8C  gsize_8C  facies_8C  \
# 0       5.0        3.0      2.0      NaN      NaN       NaN        NaN
# 1       NaN        NaN      NaN      NaN      4.0       5.0        6.0
# 2       5.0        3.0      2.0      NaN      NaN       NaN        NaN
# 3       NaN        NaN      NaN      NaN     13.0       5.0        3.0
# 4       5.0        3.0      2.0      1.0     10.0       4.0        4.0
#
#    lith_8C  amal_8C  beds_9A  gsize_9A  facies_9A  lith_9A  amal_9A  beds_10A  \
# 0      NaN      NaN     27.0       7.0        7.0      2.0      0.0       5.0
# 1      2.0      NaN    194.0       8.0        7.0      2.0      0.0       NaN
# 2      NaN      NaN      NaN       NaN        NaN      NaN      NaN       6.0
# 3      2.0      1.0      2.0       6.0        3.0      2.0      0.0       NaN
# 4      2.0      1.0      NaN       NaN        NaN      NaN      NaN      15.0
#
#    gsize_10A  facies_10A  lith_10A  amal_10A  beds_11A  gsize_11A  facies_11A  \
# 0        3.0         3.0       1.0       NaN      53.0        3.0         6.0
# 1        NaN         NaN       NaN       NaN       NaN        NaN         NaN
# 2        3.0         3.0       1.0       NaN      10.0        7.0         3.0
# 3        NaN         NaN       NaN       NaN       NaN        NaN         NaN
# 4        3.0         4.0       1.0       NaN       1.0        3.0         3.0
#
#    lith_11A  amal_11A  beds_12A  gsize_12A  facies_12A  lith_12A  amal_12A  \
# 0       2.0       NaN      12.0        6.0         4.0       2.0       NaN
# 1       NaN       NaN       NaN        NaN         NaN       NaN       NaN
# 2       2.0       NaN       4.5        3.0         3.0       1.0       1.0
# 3       NaN       NaN      14.0        3.0         4.0       1.0       1.0
# 4       1.0       1.0       NaN        NaN         NaN       NaN       NaN
#
#    beds_13A  gsize_13A  facies_13A  lith_13A  amal_13A  beds_13B  gsize_13B  \
# 0      16.0        5.0         4.0       1.0       1.0      73.0        8.0
# 1      18.0        6.0         2.0       2.0       1.0      92.0        8.0
# 2     267.0        8.0         7.0       2.0       NaN      70.0        6.0
# 3       NaN        NaN         NaN       NaN       NaN     135.0        8.0
# 4       5.0        6.0         3.0       2.0       NaN      65.0        8.0
#
#    facies_13B  lith_13B  amal_13B
# 0         7.0       2.0       1.0
# 1         7.0       2.0       1.0
# 2         5.0       2.0       1.0
# 3         7.0       2.0       1.0
# 4         7.0       2.0       1.0

# %%
x = df.beds_3A.dropna()
len(x)
# Out:
# 259
