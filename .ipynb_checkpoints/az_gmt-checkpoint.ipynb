# %%
import pygmt as pg
import os
import pandas as pd
import numpy as np
# Out:
# Traceback (most recent call last):
#
#   File "/opt/anaconda3/envs/field/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3319, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-5-573495ef7728>", line 1, in <module>
#     import pygmt as pg
#
#   File "/opt/anaconda3/envs/field/lib/python3.7/site-packages/pygmt/__init__.py", line 15, in <module>
#     from .session_management import begin as _begin, end as _end
#
#   File "/opt/anaconda3/envs/field/lib/python3.7/site-packages/pygmt/session_management.py", line 4, in <module>
#     from .clib import Session
#
#   File "/opt/anaconda3/envs/field/lib/python3.7/site-packages/pygmt/clib/__init__.py", line 8, in <module>
#     from .session import Session
#
#   File "/opt/anaconda3/envs/field/lib/python3.7/site-packages/pygmt/clib/session.py", line 19, in <module>
#     from .loading import load_libgmt
#
# ...

# %%
os.chdir("/Users/euan-soutter/Desktop/Python/Field_Data/Azerbaijan/Data/") # Sets working directory
df = pd.read_csv("az_loc.csv")
print(df) # Displays statistical descriptions of df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a88614697954> in <module>
# ----> 1 os.chdir("/Users/euan-soutter/Desktop/Python/Field_Data/Azerbaijan/Data/") # Sets working directory
#       2 df = pd.read_csv("az_loc.csv")
#       3 print(df) # Displays statistical descriptions of df
#
# NameError: name 'os' is not defined

# %%
region = [48.12, 48.43, 41.17, 41.23]
fig = pg.Figure()
fig.coast(region = region, projection='M20c', frame='a', land='grey')
fig.plot(x = df.long, y=df.lat, color='white',style='c0.2c')
fig.show()

# %%
topo = pg.datasets.load_earth_relief('02m')
region=[35,55,37,46]
fig = pg.Figure()
fig.basemap(R = region, projection='N20c', frame='a')
fig.grdimage(topo, cmap='geo')
fig.colorbar(position='JCR+v', frame=['x2000','y+lm'])
fig.show()

# %%
topo = pg.datasets.load_earth_relief('02m')
region=[-117,-113,31,53]
fig = pg.Figure()
fig.basemap(R = region, J='N20c', frame='a')
fig.grdimage(topo, cmap='geo')
fig.colorbar(position='JCR+v', frame=['x2000','y+lm'])
# fig.savefig('west_america.png',dpi=400)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bcc0ba995ab7> in <module>
# ----> 1 topo = pg.datasets.load_earth_relief('02m')
#       2 region=[-117,-113,31,53]
#       3 fig = pg.Figure()
#       4 fig.basemap(R = region, J='N20c', frame='a')
#       5 fig.grdimage(topo, cmap='geo')
#
# NameError: name 'pg' is not defined

# %%
import elevation

# clip the SRTM1 30m DEM of Rome and save it to Rome-DEM.tif
elevation.clip(bounds=(12.6, 41.9, 12.65, 42), output='Rome-DEM.tif', product='SRTM3')
# clean up stale temporary files and fix the cache in the event of a server error
elevation.clean()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a1e2256b9b52> in <module>
#       2
#       3 # clip the SRTM1 30m DEM of Rome and save it to Rome-DEM.tif
# ----> 4 elevation.clip(bounds=(12.6, 41.9, 12.65, 42), output='Rome-DEM.tif', product='SRTM3')
#       5 # clean up stale temporary files and fix the cache in the event of a server error
#       6 elevation.clean()
#
# /opt/anaconda3/envs/field/lib/python3.7/site-packages/elevation/datasource.py in clip(bounds, output, margin, **kwargs)
#     179     """
#     180     bounds = build_bounds(bounds, margin=margin)
# --> 181     datasource_root = seed(bounds=bounds, **kwargs)
#     182     do_clip(datasource_root, bounds, output, **kwargs)
#     183
#
# /opt/anaconda3/envs/field/lib/python3.7/site-packages/elevation/datasource.py in seed(cache_dir, product, bounds, max_download_tiles, **kwargs)
#     151
# ...
