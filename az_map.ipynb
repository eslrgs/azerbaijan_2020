# %% [markdown]
# ## Code used for Cumberpatch et al (2020)
# ### 'Evolution of a mixed siliciclastic-carbonate deep-marine system on an unstable margin: the Cretaceous of the Eastern Greater Caucasus, Azerbaijan'

# %% [markdown]
# ### Import packages

# %%
## Code used for Cumberpatch et al (2020)
### 'Evolution of a mixed siliciclastic-carbonate deep-marine system on an unstable margin: the Cretaceous of the Eastern Greater Caucasus, Azerbaijan'

### Import packagesimport pandas as pd
from ipyleaflet import Map, Marker, Popup, basemaps, ImageOverlay, Polygon, LayersControl, Polyline, FullScreenControl, MarkerCluster, CircleMarker, Icon, AwesomeIcon
import matplotlib.pyplot as plt
from ipywidgets import HTML
import os
import pandas as pd

# !jupyter nbextension enable --py widgetsnbextension --sys-prefix
# !jupyter nbextension enable --py --sys-prefix ipyleaflet
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# Enabling notebook extension jupyter-leaflet/extension...
#       - Validating: OK

# %% [markdown]
# ### Load data

# %%
os.chdir("/Users/euan-soutter/Desktop/Python/Field/azerbaijan_2020/Data/") # Sets working directory
df = pd.read_csv("az_loc.csv")
df
# Out:
#     log        lat       long     z  meanthickness  meangsize
# 0    1A  41.199444  48.245278  1750      91.166667   3.000000
# 1    1B  41.201667  48.254444  1680      42.444444   3.666667
# 2    1C  41.201944  48.251667  1530      27.112903   3.693548
# 3    2B  41.195161  48.259659  1678      16.173034   3.685393
# 4    3B  41.202191  48.261274  1592      16.913043   3.804348
# 5    4A  41.202454  48.268674  1656      20.407605   4.239544
# 6    5A  41.200300  48.264785  1707      97.727273   5.272727
# 7    5B  41.200687  48.264507  1726      31.000000   6.375000
# 8    5C  41.204544  48.267427  1598      11.857143   4.714286
# 9    6A  41.135175  48.571891  1488      50.000000   7.000000
# 10   7A  41.097369  48.628450  1532            NaN        NaN
# 11   7B  41.094108  48.630320  1613            NaN        NaN
# 12   7C  41.093400  48.631840  1623            NaN        NaN
# 13   7D  41.093593  48.629360  1564            NaN        NaN
# ...

# %% [markdown]
# ### Plot interactive location map

# %%
center = [41.2, 48.3]
zoom = 11
opacity = 0.5

# icon = AwesomeIcon(name=' fa-chevron-circle-down', icon_size = [5,5], icon_color='black')
icon = Icon(icon_url="https://img.icons8.com/material/24/000000/bookmark-ribbon--v1.png" ,icon_size=[5,5])

m = Map(basemap=basemaps.OpenTopoMap, center=center, zoom=zoom)
# m = Map(basemap=basemaps.OpenStreetMap.BlackAndWhite, center=center, zoom=zoom)

bochud = ImageOverlay(url='az_bochud.png', bounds=((41, 47), (41.92, 49)), opacity = opacity)
azmap = ImageOverlay(url='az_map.png', bounds=((41, 48), (41.92, 49)), opacity = opacity)

m.add_layer(bochud)
m.add_layer(azmap)

dfn = df[['long', 'lat']]

locations = [tuple(r) for r in dfn.to_numpy()]

for i, k in locations:
    markers = Marker(location=(k, i), icon=icon)
    m.add_layer(markers)
    
# polygon = Polygon(locations= [[(40, 47),(41, 47),(41, 49),(40, 49)]], color="green", fill_color="green")
        
control = LayersControl(position='topright')
m.add_control(control)
m.add_control(FullScreenControl())

m
# Out:
# Map(center=[41.2, 48.3], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…

# %% [markdown]
# ### Check data

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('az_map.png')
imgplot = plt.imshow(img)
plt.show()

# %%
# for lon, lat in zip(longitudes, latitudes):
#     markers.append(Marker(location=(lon, lat)))
    
# marker_cluster = MarkerCluster(markers=markers)

# m.add_layer(marker_cluster);

# m.add_layer(marker_cluster)
